# %%
# !pip install xgboost lightgbm catboost

# %%
cd ../
# Out:
# d:\Personal\project_temp\ReliSource\1st_phase\ReliSource

# %%
import pandas as pd

train_data =  pd.read_csv('data/cleaned_train_iffat.csv')
test_data =  pd.read_csv('data/test.csv')
train_data
# Out:
#        UID  col_4       y  col_0_numerical  col_1_numerical  col_2_numerical  \
# 0        0    100  237000                0                0                2
# 1        1    100   86193                1                0               11
# 2        2      0  169200                0                0               18
# 3        3    100   58000                2                0               11
# 4        4      0  235000                0                0               67
# ...    ...    ...     ...              ...              ...              ...
# 2623  2623      0  102100                1                0                2
# 2624  2624      0  129300                0                0                8
# 2625  2625    100  275300                0                0                7
# 2626  2626    100  150000                0                0               11
# 2627  2627    100  191475                0                0                2
#
#       col_3_numerical  col_5_numerical  col_6_numerical
# 0                   1                1                2
# 1                   4                4                2
# 2                   0                0                2
# 3                   1                1                2
# 4                   1                1                2
# ...               ...              ...              ...
# 2623                1                1                2
# 2624                1                1                2
# 2625                1                1                2
# 2626                1                1                2
# 2627                1                1                2
#
# [2628 rows x 9 columns]

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error
# from sklearn.linear_model import LinearRegression, Ridge, Lasso
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import (
#     RandomForestRegressor,
#     GradientBoostingRegressor,
#     AdaBoostRegressor,
# )
# import xgboost as xgb
# import lightgbm as lgb
# import catboost as catb
# from sklearn.svm import SVR
# from sklearn.linear_model import ElasticNet
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.linear_model import BayesianRidge
# import random
# from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# import logging
# import datetime  # Import the datetime module

# # Generate a timestamp
# timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# # Configure logging with the timestamp in the log filename
# log_filename = f'logs/model_selection_{timestamp}.log'  # Include the timestamp in the filename

# logging.basicConfig(filename=log_filename, level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

# # Function to log messages to both the console and the log file
# def log_message(message):
#     print(message)  # Print to console
#     logging.info(message)  # Log to file

# # The rest of your code remains the same...


# # Split the data into training, validation, and test sets
# for seed_number in range(100):
#     log_message(f"\n====================== result for random seed: {seed_number} ======================")
#     X_train, X_val, y_train, y_val = train_test_split(train_data.drop(columns=["y","UID","col_4"]), train_data["y"], test_size=0.1, random_state=seed_number)

#     # Define a list of regression models to compare
#     # Define a list of regression models to compare, including previous models
#     models = {
#         'Linear Regression': LinearRegression(),
#         'Ridge Regression': Ridge(),
#         'Lasso Regression': Lasso(),
#         'Decision Tree Regressor': DecisionTreeRegressor(),
#         'Random Forest Regressor': RandomForestRegressor(),
#         'Gradient Boosting Regressor': GradientBoostingRegressor(),
#         'AdaBoost Regressor': AdaBoostRegressor(),
#         'XGBoost Regressor': xgb.XGBRegressor(),
#         'LightGBM Regressor': lgb.LGBMRegressor(verbose=-1),
#         'CatBoost Regressor': catb.CatBoostRegressor(silent=True),
#         'ElasticNet Regression': ElasticNet(),
#         'K-Nearest Neighbors': KNeighborsRegressor(),
#         'Support Vector Regressor': SVR(),
#         'Bayesian Ridge Regression': BayesianRidge(),
#     }

#     # Define hyperparameter grids for each model, including previous models
#     param_grids = {
#         'Linear Regression': {},
#         'Ridge Regression': {'alpha': [0.1, 1.0, 10.0]},
#         'Lasso Regression': {'alpha': [0.1, 1.0, 10.0]},
#         'Decision Tree Regressor': {'max_depth': [None, 10, 20, 30]},
#         'Random Forest Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20, 30]},
#         'Gradient Boosting Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
#         'AdaBoost Regressor': {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
#         'XGBoost Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
#         'LightGBM Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
#         'CatBoost Regressor': {'iterations': [50, 100, 200], 'depth': [4, 6, 8]},
#         'ElasticNet Regression': {'alpha': [0.1, 1.0, 10.0], 'l1_ratio': [0.25, 0.5, 0.75]},
#         'K-Nearest Neighbors': {'n_neighbors': [3, 5, 7, 10], 'weights': ['uniform', 'distance']},
#         'Support Vector Regressor': {'C': [0.1, 1.0, 10.0], 'kernel': ['linear', 'rbf']},
#         'Bayesian Ridge Regression': {'max_iter': [100, 300, 500], 'alpha_1': [1e-6, 1e-7], 'alpha_2': [1e-6, 1e-7]},
#     }


#     # Initialize variables to store best models, their RMSE scores, and best parameters
#     best_models = {}
#     best_rmse_scores = {}
#     best_parameters = {}

#     # Hyperparameter tuning loop
#     for model_name, model in models.items():
#         param_grid = param_grids[model_name]
        
#         if param_grid:
#             search = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
#             search.fit(X_train, y_train)
            
#             best_model = search.best_estimator_
#             best_rmse = np.sqrt(-search.best_score_)
#             best_param = search.best_params_
#         else:
#             model.fit(X_train, y_train)
#             best_model = model
#             y_pred = model.predict(X_val)
#             best_rmse = np.sqrt(mean_squared_error(y_val, y_pred))
#             best_param = None
        
#         best_models[model_name] = best_model
#         best_rmse_scores[model_name] = best_rmse
#         best_parameters[model_name] = best_param
#         log_message(f"Best {model_name} RMSE: {best_rmse}")

#     # Find the model with the lowest RMSE
#     best_model_name = min(best_rmse_scores, key=best_rmse_scores.get)
#     log_message(f"Best Model: {best_model_name} (RMSE: {best_rmse_scores[best_model_name]})")

#     # Print the best parameters for the best model
#     log_message("Best Parameters for Best Model:")
#     log_message(best_parameters[best_model_name])

#     # # Evaluate the best model on the test data
#     # best_model = best_models[best_model_name]
#     # y_test_pred = best_model.predict(X_test)
#     # test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
#     # print(f"Test RMSE of Best Model: {test_rmse}")

# %%
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    AdaBoostRegressor,
)
import xgboost as xgb
import lightgbm as lgb
import catboost as catb
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge
import random
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import logging
import datetime  # Import the datetime module

# Generate a timestamp
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Configure logging with the timestamp in the log filename
log_filename = f'logs/model_selection_{timestamp}.log'  # Include the timestamp in the filename

logging.basicConfig(filename=log_filename, level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

# Function to log messages to both the console and the log file
def log_message(message):
    print(message)  # Print to console
    logging.info(message)  # Log to file

# The rest of your code remains the same...


# Split the data into training, validation, and test sets
for seed_number in range(100):
    log_message(f"\n====================== result for random seed: {seed_number} ======================")
    X_train, X_val, y_train, y_val = train_test_split(train_data.drop(columns=["y","UID","col_4"]), train_data["y"], test_size=0.1, random_state=seed_number)

    # Define a list of regression models to compare
    models = {
        'Linear Regression': LinearRegression(),
        'Ridge Regression': Ridge(),
        'Lasso Regression': Lasso(),
        'Decision Tree Regressor': DecisionTreeRegressor(),
        'Random Forest Regressor': RandomForestRegressor(),
        'Gradient Boosting Regressor': GradientBoostingRegressor(),
        'AdaBoost Regressor': AdaBoostRegressor(),
        'XGBoost Regressor': xgb.XGBRegressor(),
        'LightGBM Regressor': lgb.LGBMRegressor(verbose=-1),
        'CatBoost Regressor': catb.CatBoostRegressor(silent=True),
        'ElasticNet Regression': ElasticNet(),
        'K-Nearest Neighbors': KNeighborsRegressor(),
        'Support Vector Regressor': SVR(),
        'Bayesian Ridge Regression': BayesianRidge(),
    }

    # Define hyperparameter grids for each model, including previous models
    param_grids = {
        'Linear Regression': {},
        'Ridge Regression': {'alpha': [0.1, 1.0, 10.0]},
        'Lasso Regression': {'alpha': [0.1, 1.0, 10.0]},
        'Decision Tree Regressor': {'max_depth': [None, 10, 20, 30]},
        'Random Forest Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20, 30]},
        'Gradient Boosting Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
        'AdaBoost Regressor': {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
        'XGBoost Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
        'LightGBM Regressor': {'n_estimators': [50, 100, 200], 'max_depth': [3, 4, 5]},
        'CatBoost Regressor': {'iterations': [50, 100, 200], 'depth': [4, 6, 8]},
        'ElasticNet Regression': {'alpha': [0.1, 1.0, 10.0], 'l1_ratio': [0.25, 0.5, 0.75]},
        'K-Nearest Neighbors': {'n_neighbors': [3, 5, 7, 10], 'weights': ['uniform', 'distance']},
        'Support Vector Regressor': {'C': [0.1, 1.0, 10.0], 'kernel': ['linear', 'rbf']},
        'Bayesian Ridge Regression': {'max_iter': [100, 300, 500], 'alpha_1': [1e-6, 1e-7], 'alpha_2': [1e-6, 1e-7]},
    }


    # Initialize variables to store best models, their RMSE scores, and best parameters
    best_models = {}
    best_rmse_scores = {}
    best_parameters = {}

    # Hyperparameter tuning loop with k-fold cross-validation (k=10)
    for model_name, model in models.items():
        param_grid = param_grids[model_name]
        
        best_model = None  # Initialize best_model
        best_param = None  # Initialize best_param
        
        if param_grid:
            search = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=10)  # Change cv to 10
            search.fit(X_train, y_train)
            
            best_model = search.best_estimator_
            best_rmse = np.sqrt(-search.best_score_)
            best_param = search.best_params_
        else:
            # Perform k-fold cross-validation with k=10
            scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=10)  # Change cv to 10
            
            # Find the best RMSE score and corresponding model
            best_rmse = np.sqrt(-scores.max())
        
        best_models[model_name] = best_model
        best_rmse_scores[model_name] = best_rmse
        best_parameters[model_name] = best_param
        log_message(f"Best {model_name} RMSE: {best_rmse}")

    # Find the model with the lowest RMSE
    best_model_name = min(best_rmse_scores, key=best_rmse_scores.get)
    log_message(f"Best Model: {best_model_name} (RMSE: {best_rmse_scores[best_model_name]})")

    # Print the best parameters for the best model
    log_message("Best Parameters for Best Model:")
    log_message(best_parameters[best_model_name])

    # # Evaluate the best model on the test data
    # best_model = best_models[best_model_name]
    # y_test_pred = best_model.predict(X_test)
    # test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    # print(f"Test RMSE of Best Model: {test_rmse}")

# %%
# import pandas as pd
# import numpy as np
# import datetime
# import logging
# import tensorflow as tf
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# # Load the dataset
# data = train_data

# # Extract the features and target variable
# X = data.drop(columns=['UID', 'col_4', 'y'])
# y = data['y']

# # Generate a timestamp
# timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# # Configure logging with the timestamp in the log filename
# log_filename = f'logs/model_selection_{timestamp}.log'  # Include the timestamp in the filename

# logging.basicConfig(filename=log_filename, level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

# # Function to log messages to both the console and the log file
# def log_message(message):
#     print(message)  # Print to console
#     logging.info(message)  # Log to file

# # Split the data into training and validation sets
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# # Create a feedforward neural network (FNN) model for regression
# model = Sequential([
#     Dense(64, activation='relu', input_dim=X_train.shape[1]),
#     Dense(32, activation='relu'),
#     Dense(1)  # Output layer for regression
# ])

# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Train the model
# model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2)

# # Make predictions on the validation set
# y_val_pred = model.predict(X_val)

# # Calculate RMSE on the validation set
# val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
# log_message(f"Validation RMSE of FNN Model: {val_rmse}")


# # Now, you can use the trained CNN model to make predictions on your test data and save the submission CSV as previously discussed.
# Out:
# Epoch 1/100
# 74/74 - 1s - loss: 22921928704.0000 - 832ms/epoch - 11ms/step
# Epoch 2/100
# 74/74 - 0s - loss: 22895155200.0000 - 330ms/epoch - 4ms/step
# Epoch 3/100
# 74/74 - 0s - loss: 22778888192.0000 - 322ms/epoch - 4ms/step
# Epoch 4/100
# 74/74 - 0s - loss: 22473703424.0000 - 342ms/epoch - 5ms/step
# Epoch 5/100
# 74/74 - 0s - loss: 21901391872.0000 - 373ms/epoch - 5ms/step
# Epoch 6/100
# 74/74 - 0s - loss: 21040580608.0000 - 392ms/epoch - 5ms/step
# Epoch 7/100
# 74/74 - 0s - loss: 19970590720.0000 - 371ms/epoch - 5ms/step
# Epoch 8/100
# 74/74 - 0s - loss: 18829895680.0000 - 344ms/epoch - 5ms/step
# Epoch 9/100
# 74/74 - 0s - loss: 17768368128.0000 - 337ms/epoch - 5ms/step
# Epoch 10/100
# 74/74 - 0s - loss: 16846912512.0000 - 360ms/epoch - 5ms/step
# Epoch 11/100
# 74/74 - 0s - loss: 16090728448.0000 - 330ms/epoch - 4ms/step
# Epoch 12/100
# 74/74 - 0s - loss: 15500826624.0000 - 325ms/epoch - 4ms/step
# Epoch 13/100
# 74/74 - 0s - loss: 15028276224.0000 - 337ms/epoch - 5ms/step
# Epoch 14/100
# 74/74 - 0s - loss: 14654976000.0000 - 327ms/epoch - 4ms/step
# Epoch 15/100
# 74/74 - 0s - loss: 14345841664.0000 - 330ms/epoch - 4ms/step
# Epoch 16/100
# 74/74 - 0s - loss: 14080910336.0000 - 349ms/epoch - 5ms/step
# Epoch 17/100
# 74/74 - 0s - loss: 13844242432.0000 - 328ms/epoch - 4ms/step
# Epoch 18/100
# 74/74 - 0s - loss: 13632992256.0000 - 324ms/epoch - 4ms/step
# Epoch 19/100
# 74/74 - 0s - loss: 13428308992.0000 - 344ms/epoch - 5ms/step
# Epoch 20/100
# 74/74 - 0s - loss: 13236293632.0000 - 332ms/epoch - 4ms/step
# Epoch 21/100
# 74/74 - 0s - loss: 13049654272.0000 - 338ms/epoch - 5ms/step
# Epoch 22/100
# 74/74 - 0s - loss: 12867309568.0000 - 344ms/epoch - 5ms/step
# Epoch 23/100
# 74/74 - 0s - loss: 12688100352.0000 - 333ms/epoch - 5ms/step
# Epoch 24/100
# 74/74 - 0s - loss: 12515055616.0000 - 330ms/epoch - 4ms/step
# Epoch 25/100
# 74/74 - 0s - loss: 12332511232.0000 - 345ms/epoch - 5ms/step
# Epoch 26/100
# 74/74 - 0s - loss: 12152605696.0000 - 335ms/epoch - 5ms/step
# Epoch 27/100
# 74/74 - 0s - loss: 11975402496.0000 - 327ms/epoch - 4ms/step
# Epoch 28/100
# 74/74 - 0s - loss: 11791799296.0000 - 343ms/epoch - 5ms/step
# Epoch 29/100
# 74/74 - 0s - loss: 11599685632.0000 - 333ms/epoch - 5ms/step
# Epoch 30/100
# 74/74 - 0s - loss: 11406308352.0000 - 323ms/epoch - 4ms/step
# Epoch 31/100
# 74/74 - 0s - loss: 11208644608.0000 - 344ms/epoch - 5ms/step
# Epoch 32/100
# 74/74 - 0s - loss: 11007584256.0000 - 346ms/epoch - 5ms/step
# Epoch 33/100
# 74/74 - 0s - loss: 10797685760.0000 - 348ms/epoch - 5ms/step
# Epoch 34/100
# 74/74 - 0s - loss: 10580643840.0000 - 334ms/epoch - 5ms/step
# Epoch 35/100
# 74/74 - 0s - loss: 10361056256.0000 - 361ms/epoch - 5ms/step
# Epoch 36/100
# 74/74 - 0s - loss: 10131282944.0000 - 327ms/epoch - 4ms/step
# Epoch 37/100
# 74/74 - 0s - loss: 9895328768.0000 - 333ms/epoch - 4ms/step
# Epoch 38/100
# 74/74 - 0s - loss: 9655217152.0000 - 332ms/epoch - 4ms/step
# Epoch 39/100
# 74/74 - 0s - loss: 9407754240.0000 - 332ms/epoch - 4ms/step
# Epoch 40/100
# 74/74 - 0s - loss: 9156803584.0000 - 331ms/epoch - 4ms/step
# Epoch 41/100
# 74/74 - 0s - loss: 8898818048.0000 - 342ms/epoch - 5ms/step
# Epoch 42/100
# 74/74 - 0s - loss: 8633795584.0000 - 339ms/epoch - 5ms/step
# Epoch 43/100
# 74/74 - 0s - loss: 8371982336.0000 - 344ms/epoch - 5ms/step
# Epoch 44/100
# 74/74 - 0s - loss: 8101876224.0000 - 343ms/epoch - 5ms/step
# Epoch 45/100
# 74/74 - 0s - loss: 7835207168.0000 - 335ms/epoch - 5ms/step
# Epoch 46/100
# 74/74 - 0s - loss: 7570527232.0000 - 371ms/epoch - 5ms/step
# Epoch 47/100
# 74/74 - 0s - loss: 7312112640.0000 - 339ms/epoch - 5ms/step
# Epoch 48/100
# 74/74 - 0s - loss: 7059650560.0000 - 331ms/epoch - 4ms/step
# Epoch 49/100
# 74/74 - 0s - loss: 6817363456.0000 - 319ms/epoch - 4ms/step
# Epoch 50/100
# 74/74 - 0s - loss: 6583473152.0000 - 327ms/epoch - 4ms/step
# Epoch 51/100
# 74/74 - 0s - loss: 6364024320.0000 - 326ms/epoch - 4ms/step
# Epoch 52/100
# 74/74 - 0s - loss: 6158244864.0000 - 333ms/epoch - 5ms/step
# Epoch 53/100
# 74/74 - 0s - loss: 5968623104.0000 - 316ms/epoch - 4ms/step
# Epoch 54/100
# 74/74 - 0s - loss: 5795694592.0000 - 340ms/epoch - 5ms/step
# Epoch 55/100
# 74/74 - 0s - loss: 5640560640.0000 - 327ms/epoch - 4ms/step
# Epoch 56/100
# 74/74 - 0s - loss: 5500949504.0000 - 337ms/epoch - 5ms/step
# Epoch 57/100
# 74/74 - 0s - loss: 5381757440.0000 - 360ms/epoch - 5ms/step
# Epoch 58/100
# 74/74 - 0s - loss: 5277440512.0000 - 338ms/epoch - 5ms/step
# Epoch 59/100
# 74/74 - 0s - loss: 5187254784.0000 - 326ms/epoch - 4ms/step
# Epoch 60/100
# 74/74 - 0s - loss: 5111370752.0000 - 335ms/epoch - 5ms/step
# Epoch 61/100
# 74/74 - 0s - loss: 5046373888.0000 - 335ms/epoch - 5ms/step
# Epoch 62/100
# 74/74 - 0s - loss: 4992754688.0000 - 326ms/epoch - 4ms/step
# Epoch 63/100
# 74/74 - 0s - loss: 4947092992.0000 - 333ms/epoch - 4ms/step
# Epoch 64/100
# 74/74 - 0s - loss: 4909890560.0000 - 323ms/epoch - 4ms/step
# Epoch 65/100
# 74/74 - 0s - loss: 4877064192.0000 - 332ms/epoch - 4ms/step
# Epoch 66/100
# 74/74 - 0s - loss: 4849053696.0000 - 330ms/epoch - 4ms/step
# Epoch 67/100
# 74/74 - 0s - loss: 4825673216.0000 - 341ms/epoch - 5ms/step
# Epoch 68/100
# 74/74 - 0s - loss: 4803531264.0000 - 348ms/epoch - 5ms/step
# Epoch 69/100
# 74/74 - 0s - loss: 4783333376.0000 - 352ms/epoch - 5ms/step
# Epoch 70/100
# 74/74 - 0s - loss: 4766818816.0000 - 330ms/epoch - 4ms/step
# Epoch 71/100
# 74/74 - 0s - loss: 4749062144.0000 - 338ms/epoch - 5ms/step
# Epoch 72/100
# 74/74 - 0s - loss: 4733481472.0000 - 333ms/epoch - 4ms/step
# Epoch 73/100
# 74/74 - 0s - loss: 4718793216.0000 - 325ms/epoch - 4ms/step
# Epoch 74/100
# 74/74 - 0s - loss: 4704214016.0000 - 333ms/epoch - 4ms/step
# Epoch 75/100
# 74/74 - 0s - loss: 4691555840.0000 - 339ms/epoch - 5ms/step
# Epoch 76/100
# 74/74 - 0s - loss: 4674912256.0000 - 334ms/epoch - 5ms/step
# Epoch 77/100
# 74/74 - 0s - loss: 4662392832.0000 - 345ms/epoch - 5ms/step
# Epoch 78/100
# 74/74 - 0s - loss: 4650287616.0000 - 335ms/epoch - 5ms/step
# Epoch 79/100
# 74/74 - 0s - loss: 4634368000.0000 - 330ms/epoch - 4ms/step
# Epoch 80/100
# 74/74 - 0s - loss: 4622180352.0000 - 334ms/epoch - 5ms/step
# Epoch 81/100
# 74/74 - 0s - loss: 4609647616.0000 - 341ms/epoch - 5ms/step
# Epoch 82/100
# 74/74 - 0s - loss: 4595521536.0000 - 324ms/epoch - 4ms/step
# Epoch 83/100
# 74/74 - 0s - loss: 4583154176.0000 - 329ms/epoch - 4ms/step
# Epoch 84/100
# 74/74 - 0s - loss: 4569935360.0000 - 349ms/epoch - 5ms/step
# Epoch 85/100
# 74/74 - 0s - loss: 4556713472.0000 - 329ms/epoch - 4ms/step
# Epoch 86/100
# 74/74 - 0s - loss: 4543960576.0000 - 337ms/epoch - 5ms/step
# Epoch 87/100
# 74/74 - 0s - loss: 4530983936.0000 - 336ms/epoch - 5ms/step
# Epoch 88/100
# 74/74 - 0s - loss: 4518238720.0000 - 333ms/epoch - 5ms/step
# Epoch 89/100
# 74/74 - 0s - loss: 4506728448.0000 - 332ms/epoch - 4ms/step
# Epoch 90/100
# 74/74 - 0s - loss: 4492551168.0000 - 340ms/epoch - 5ms/step
# Epoch 91/100
# 74/74 - 0s - loss: 4481321984.0000 - 353ms/epoch - 5ms/step
# Epoch 92/100
# 74/74 - 0s - loss: 4468385280.0000 - 338ms/epoch - 5ms/step
# Epoch 93/100
# 74/74 - 0s - loss: 4455830016.0000 - 333ms/epoch - 5ms/step
# Epoch 94/100
# 74/74 - 0s - loss: 4443265024.0000 - 332ms/epoch - 4ms/step
# Epoch 95/100
# 74/74 - 0s - loss: 4430470144.0000 - 332ms/epoch - 4ms/step
# Epoch 96/100
# 74/74 - 0s - loss: 4417205248.0000 - 333ms/epoch - 4ms/step
# Epoch 97/100
# 74/74 - 0s - loss: 4406090240.0000 - 319ms/epoch - 4ms/step
# Epoch 98/100
# 74/74 - 0s - loss: 4394107904.0000 - 330ms/epoch - 4ms/step
# Epoch 99/100
# 74/74 - 0s - loss: 4380036096.0000 - 355ms/epoch - 5ms/step
# Epoch 100/100
# 74/74 - 0s - loss: 4367221248.0000 - 331ms/epoch - 4ms/step
# 9/9 [==============================] - 0s 2ms/step
# Validation RMSE of FNN Model: 67794.83838884387
